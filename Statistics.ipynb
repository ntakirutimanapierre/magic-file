# %%
import numpy as np

# %%
import scipy.stats as st
import matplotlib.pyplot as plt
np.random.seed(1234)
sample=np.random.normal(2,0.3,1000)
plt.figure(figsize=(10,5))

plt.title('Histogram of normal')
cdf=st.binom(20, 0.1)
plt.subplot(1,2,1)
plt.hist(sample,bins=40,color='red')
plt.subplot(1,2,2)
#plt.hist(cdf, bins=50)
plt.show()
print()

# %%
>>> import scipy.stats
>>> import numpy as np
>>> import matplotlib.pyplot as plt
>>> np.random.seed(1234)
>>> samples=np.random.lognormal(mean=1.,sigma=.4,size=10000)
>>> shape,loc,scale=scipy.stats.lognorm.fit(samples,floc=0)
>>> num_bins=50
plt.figure(figsize=(10,5))
>>> counts,edges,patches=plt.hist(samples,bins=num_bins)
>>> centers=0.5*(edges[:-1]+edges[1:])
>>> cdf=scipy.stats.lognorm.cdf(edges,shape,loc=loc,scale=scale)
>>> prob=np.diff(cdf)
plt.figure(figsize=(10,5))
>>> plt.plot(centers,samples.size*prob,'k-',linewidth=2)
plt.show()

# %%
sample.shape
# Out:
# (1000,)

# %%
#dir(st)

# %%
st.expect(c)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-3ebcb78f2800> in <module>
# ----> 1 st.expect(c)
#
# AttributeError: module 'scipy.stats' has no attribute 'expect'

# %%
st.bernoulli?

# %%
a=st.norm.rvs(3,2,size=1000000)
b=st.gamma.rvs(3,2, size=1000000)
c=a+b
plt.figure(figsize=(15,2))
plt.subplot(1,3,1)

plt.hist(a,bins=50)


plt.subplot(1,3,2)

plt.hist(b,bins=50)
plt.title('GAmma')
plt.subplot(1,3,3)

plt.hist(c,bins=50)
plt.show()

# %%
st.gamma?
